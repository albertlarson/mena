# %%
import glob
import xarray as xr
import matplotlib.pyplot as plt
# Out:
# /work/albertl_uri_edu/.conda/envs/sm/lib/python3.9/site-packages/xarray/backends/cfgrib_.py:27: UserWarning: Failed to load cfgrib - most likely there is a problem accessing the ecCodes library. Try `import cfgrib` to get the full error message
#   warnings.warn(

# %%
x = sorted(glob.glob('gldas__v20__clip__monthly/*.nc'))
x0 = 'gldas__v20__clip__monthly/ksa_gld_v20_monthly_2000april.nc'
print(len(x))
x1 = xr.open_dataset(x0)
x1
# Out:
# 540
# <xarray.Dataset>
# Dimensions:   (lat: 120, lon: 140)
# Coordinates:
#   * lon       (lon) float32 30.12 30.38 30.62 30.88 ... 64.12 64.38 64.62 64.88
#   * lat       (lat) float32 10.12 10.38 10.62 10.88 ... 39.12 39.38 39.62 39.88
# Data variables:
#     Rainfall  (lat, lon) float32 ...
# Attributes:
#     timeframe of observation:  april 2000

# %%
y = sorted(glob.glob('gldas__v21__clip__monthly/*.nc'))
print(len(x))
# Out:
# 540

# %%
y0 = y[0]
y1 = xr.open_dataset(y0)
y1
# Out:
# <xarray.Dataset>
# Dimensions:   (lat: 120, lon: 140)
# Coordinates:
#   * lon       (lon) float32 30.12 30.38 30.62 30.88 ... 64.12 64.38 64.62 64.88
#   * lat       (lat) float32 10.12 10.38 10.62 10.88 ... 39.12 39.38 39.62 39.88
# Data variables:
#     Rainfall  (lat, lon) float32 ...
# Attributes:
#     timeframe of observation:  april 2000

# %%
plt.pcolormesh(x1.Rainfall,cmap='cividis')
cbr = plt.colorbar()
plt.figure()
plt.pcolormesh(y1.Rainfall,cmap='cividis')
cbr=plt.colorbar()

# %%
# for a in glob.glob('gldas__v21__clip__monthly/'):
#     shutil.rmtree(a)

# %%
# shutil.make_archive('v21_monthly','zip','gldas__v21__clip__monthly/')
# Out:
# '/work/albertl_uri_edu/mid_e/v21_monthly.zip'

# %%
# shutil.make_archive('v20_monthly','zip','gldas__v20__clip__monthly/')
# Out:
# '/work/albertl_uri_edu/mid_e/v20_monthly.zip'
